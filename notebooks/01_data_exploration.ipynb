# %% [markdown]
# # 01 — Data Exploration
#
# Scratch space for exploring each raw data source before writing production code in `src/data/`.
# Use this to answer: what variable names does each dataset actually use, what does the grid look like, does a quicklook plot look like ice or noise.
#
# Nothing in here is imported by the pipeline — treat it as disposable. If something here turns out to be reusable logic, move it into `src/` instead of importing this notebook.

# %%
import sys
sys.path.append("..")

from src.utils.grid import GRID, lat_lon_bounds
print(GRID)
print(lat_lon_bounds())
